# %% [markdown]
# # Soal FGD Rabu sesi pagi
#
# 1. Berikut ini adalah tiga variabel yang menyimpan value dengan tipe boolean. Dengan menggunakan variabel tersebut, cobalah untuk mengerjakan soal 1 - 5 ! (Akan lebih seru jika kamu menebak terlebih dahulu hasilnya, kemudian baru implementasikan ke dalam kode program. Jika terdapat error, cobalah untuk menyelesaikannya sendiri terlebih dahulu).

# %% [markdown]
# NO 1
#
#
# a = False
#
# b = True
#
# c = False

# %% [markdown]
# 1. b and c = False
# 2. b or c = True
# 3. not a and b =  True
# 4. (a and b) or not c = False
# 5. not b and not (a or c) = False

# %%
# NO 2
print('Hello!')
something = input("Enter something: ")
print ("You entered: " + something)
# Out:
# Hello!
# Enter something: Hello!
# You entered: Hello!

# %%
# NO 3
print('Hello!')
something = input("Enter something: ")
if (something =='Hello!'):
    print("Hello for you too!")
elif (something == 'hi'):
    print('Hi there!')
else:
    print("I don't know what, " + something, "means.")
# Out:
# Hello!
# Enter something: Hello
# I don't know what, Hello means.

# %%
# NO 4
for i in range(0,100):
    print("halo hai halo hai...98x !.")
# Out:
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# halo hai halo hai...98x !.
# ...

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# 5. In this exercise, you are going to practice using conditionals (if, elif, else). You will write a small program that will determine the result of a rock, paper, scissors game, given Player 1 and Player 2’s choices. Your program will print out the result. Here are the rules of the game:
#
# Buatlah game suit batu-gunting-kertas sederhana. Di dalam program tersebut terdapat dua orang pemain yang dapat memilih batu/gunting/kertas menggunakan input dari pengguna. Untuk mempermudah penggambaran aturan pemenang dalam game, lengkapilah tabel kemenangan dengan menggunakan semua kemungkinan yang tersedia.

# %%
# NO 5 A

import pandas as pd

df = pd.DataFrame({
    'Pemain 1':['batu', 'gunting', 'batu', 'kertas', 'kertas'],
    'Pemain 2':['gunting', 'gunting', 'kertas', 'kertas', 'gunting'],
    'Pemenang':['Pemain 1', 'Seri', 'Pemain 2', 'Seri', 'Pemain 2']
   
})
df
# Out:
#   Pemain 1 Pemain 2  Pemenang
# 0     batu  gunting  Pemain 1
# 1  gunting  gunting      Seri
# 2     batu   kertas  Pemain 2
# 3   kertas   kertas      Seri
# 4   kertas  gunting  Pemain 2

# %%
# NO. 5 B

print('kertas')
print('gunting')
print('batu')

print("\n")
player1 = input('Player 1? ')
print()
player2 = input('Player 2? ')
print()
                
if (player1 == 'kertas' and player2 == 'kertas'):
    print("Draw!")
elif (player1 == 'kertas' and player2 == 'gunting'):
    print("Player 2 Wins!")
elif (player1 == 'kertas' and player2 == 'batu'):
    print("Player 1 Wins!")
elif (player1 == 'gunting' and player2 == 'kertas'):
    print("Player 1 Wins!")
elif (player1 == 'gunting' and player2 == 'gunting'):
    print("Draw!")
elif (player1 == 'gunting' and player2 == 'batu'):
    print("Player 2 Wins!")
elif (player1 == 'batu' and player2 == 'kertas'):
    print("Player 2")
elif (player1 == 'batu' and player2 == 'gunting'):
    print("Player 1 Wins!")
elif (player1 == 'batu' and player2 == 'batu'):
    print("Draw!")
else:
    print('\tInput tidak valid')
# Out:
# kertas
# gunting
# batu
#
#
# Player 1? batu
#
# Player 2? batu
#
# Draw!

# %%
# NO 6 

km = [1,2,3,4,5,6,7,"berhenti",8,9,10,]

for stop in km:
    if(stop == str("berhenti")):
        break
    else:
        print(stop)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
# NO 7

print("1. Donat - Rp 1250")
print("2. Bakwan - Rp 1000")
print("3. Onde-onde - Rp 800")
print("4. Lemper  - Rp 1250")
print("5. Risol - Rp 1500")

menu=["Donat","Bakwan","Onde-onde","Lemper","Risol"]
harga=[1250,1000,800,1250,1500]
while True: 
    pilihMenu=(input("Nama Menu: "))
    if pilihMenu == "1" :
        print("Kamu memesan Donat dengan harga Rp", harga[0], "terima kasih sudah berbelanja!")
    elif pilihMenu =="2":
        print("Kamu memesan Bakwan dengan harga Rp", harga[1], "terima kasih sudah berbelanja!")
    elif pilihMenu =="3":
        print("Kamu memesan Onde-onde dengan harga Rp", harga[2], "terima kasih sudah berbelanja!")
    elif pilihMenu =="4":
        print("Kamu memesan Lemper dengan harga Rp", harga[3], "terima kasih sudah berbelanja!")
    elif pilihMenu =="5":
        print("Kamu memesan Risol dengan harga Rp", harga[4], "terima kasih sudah berbelanja!")
    elif pilihMenu == "cukup":
        print("Terima kasih sudah berbelanja jajanan pasar kami!")
        break
# Out:
# 1. Donat - Rp 1250
# 2. Bakwan - Rp 1000
# 3. Onde-onde - Rp 800
# 4. Lemper  - Rp 1250
# 5. Risol - Rp 1500
# Nama Menu: 1
# Kamu memesan Donat dengan harga Rp 1250 terima kasih sudah berbelanja!
# Nama Menu: 2
# Kamu memesan Bakwan dengan harga Rp 1000 terima kasih sudah berbelanja!
# Nama Menu: 3
# Kamu memesan Onde-onde dengan harga Rp 800 terima kasih sudah berbelanja!
# Nama Menu: 4
# Kamu memesan Lemper dengan harga Rp 1250 terima kasih sudah berbelanja!
# Nama Menu: 5
# Kamu memesan Risol dengan harga Rp 1500 terima kasih sudah berbelanja!
# Nama Menu: cukup
# Terima kasih sudah berbelanja jajanan pasar kami!

# %%
# NO 8

print("\t\tMENU JAJANAN PASAR")
print("")
print("1. Donat - Rp 1250")
print("2. Bakwan - Rp 1000")
print("3. Onde-onde - Rp 800")
print("4. Lemper  - Rp 1250")
print("5. Risol - Rp 1500")
print("\n")

menu=["Donat","Bakwan","Onde-onde","Lemper","Risol"]
while True: 
    print("")
    pilihMenu = (input("\t\tInput user: "))
    if pilihMenu == "1" :
        hargaMenu = int(input("Masukkan berapa banyak kamu ingin beli? "))
        brpya = hargaMenu * 1250
        print("Kamu memesan Donat dengan harga Rp", brpya, "terima kasih sudah berbelanja!")
    elif pilihMenu =="2":
        hargaMenu = int(input("Masukkan berapa banyak kamu ingin beli? "))
        brpya = hargaMenu * 1000
        print("Kamu memesan Bakwan dengan harga Rp", brpya, "terima kasih sudah berbelanja!")
    elif pilihMenu =="3":
        hargaMenu = int(input("Masukkan berapa banyak kamu ingin beli? "))
        brpya = hargaMenu * 800
        print("Kamu memesan Onde-onde dengan harga Rp", brpya, "terima kasih sudah berbelanja!")   
    elif pilihMenu =="4":
        hargaMenu = int(input("Masukkan berapa banyak kamu ingin beli? "))
        brpya = hargaMenu * 1250
        print("Kamu memesan Lemper dengan harga Rp", brpya, "terima kasih sudah berbelanja!")
    elif pilihMenu =="5":
        hargaMenu = int(input("Masukkan berapa banyak kamu ingin beli? "))
        brpya = hargaMenu * 1500
        print("Kamu memesan Risol dengan harga Rp", brpya, "terima kasih sudah berbelanja!")
    elif pilihMenu == 'cukup':
        print("Terima kasih sudah berbelanja jajanan pasar kami!")
        break
    else:
        print("Terima kasih sudah berbelanja jajanan pasar kami!")
        break
# Out:
# 		MENU JAJANAN PASAR
#
# 1. Donat - Rp 1250
# 2. Bakwan - Rp 1000
# 3. Onde-onde - Rp 800
# 4. Lemper  - Rp 1250
# 5. Risol - Rp 1500
#
#
#
# 		Input user: 1
# Masukkan berapa banyak kamu ingin beli? 8
# Kamu memesan Donat dengan harga Rp 10000 terima kasih sudah berbelanja!
#
# 		Input user: 2
# Masukkan berapa banyak kamu ingin beli? 20
# Kamu memesan Bakwan dengan harga Rp 20000 terima kasih sudah berbelanja!
#
# 		Input user: 3
# Masukkan berapa banyak kamu ingin beli? 9
# Kamu memesan Onde-onde dengan harga Rp 7200 terima kasih sudah berbelanja!
#
# 		Input user: 4
# Masukkan berapa banyak kamu ingin beli? 10
# Kamu memesan Lemper dengan harga Rp 12500 terima kasih sudah berbelanja!
#
# 		Input user: 5
# Masukkan berapa banyak kamu ingin beli? 12
# Kamu memesan Risol dengan harga Rp 18000 terima kasih sudah berbelanja!
#
# 		Input user: cukup
# Terima kasih sudah berbelanja jajanan pasar kami!
